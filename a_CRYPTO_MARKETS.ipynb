# %%
import pandas as pd
import numpy as np
import seaborn as sns  # Add this import statement
import matplotlib.pyplot as plt
#crypto_markets = pd.read_csv("crypto-markets.csv")
crypto_markets1 = pd.read_excel("Market Capitalization CRYPTO.xlsx", sheet_name='Sheet2')
crypto_markets1
# Out:
#    Rank Symbol                 Currency    Market Cap       Volume
# 0     1    BTC            Bitcoin (BTC)  522180215248  10446579361
# 1     2     ET           Ethereum (ETH)  197700308500   5366226116
# 2     3   USDT            Tether (USDT)   83233036922  18966090739
# 3     4    BNB       Binance Coin (BNB)   33041256826    326406454
# 4     5   USDC  U.S. Dollar Coin (USDC)   26841322574    730611590
# 5     6    XRP                XRP (XRP)   25443018765   2412111277
# 6     7    ADA            Cardano (ADA)    8702105476    111306384
# 7     8   DOGE          Dogecoin (DOGE)    8642938196    134484591
# 8     9    SOL             Solana (SOL)    8008014514    172014979
# 9    10    TRX               TRON (TRX)    7643999758    159005298

# %%
plt.plot(crypto_markets1['Market Cap'])

# %%
f, ax = plt.subplots(figsize=(20, 8)) 
g = sns.barplot( y = crypto_markets1['Currency'], x = crypto_markets1['Market Cap'], palette=sns.cubehelix_palette(10, reverse=True))
plt.title("Top 10 Cryptocurrencies Market value")
ax.set_xticklabels(ax.get_xticks())
fig=plt.gcf()
plt.show()
# Out:
# C:\Users\43197\AppData\Local\Temp\ipykernel_8096\3878418273.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticks())

# %%
f, ax = plt.subplots(figsize=(20, 8)) 
g = sns.barplot( y = crypto_markets1['Currency'], x = crypto_markets1['Volume'], palette=sns.cubehelix_palette(10, reverse=True))
plt.title("Top X Cryptocurrencies Volume each 24hours")
ax.set_xticklabels(ax.get_xticks())
fig=plt.gcf()
plt.show()
# Out:
# C:\Users\43197\AppData\Local\Temp\ipykernel_8096\2074976535.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticks())

# %%
# Assuming 'date' is in datetime format, you can convert it if needed
crypto_markets['date'] = pd.to_datetime(crypto_markets['date'], format='%Y-%m-%d')

# Group the DataFrame by 'symbol' and find the index of the latest date in each group
latest_date_indices = crypto_markets.groupby('symbol')['date'].idxmax()

# Use the obtained indices to extract the rows with the latest date for each currency
latest_crypto = crypto_markets.loc[latest_date_indices]

# Now, 'latest_data_for_each_currency' contains the latest date's data for each currency
latest_crypto
# Out:
#               slug symbol        name       date  ranknow      open      high  \
# 801601       money    $$$       Money 2018-11-29     1634  0.000410  0.000410
# 217107     paccoin   $PAC     PACcoin 2018-11-29      419  0.001043  0.001054
# 331350       0xbtc  0XBTC   0xBitcoin 2018-11-29      706  0.419280  0.426576
# 537562    1337coin   1337       Elite 2018-11-29     1251  0.000031  0.000041
# 247405  firstblood    1ST  FirstBlood 2018-11-29      498  0.037822  0.037822
# ...            ...    ...         ...        ...      ...       ...       ...
# 938633      ztcoin     ZT      ZTCoin 2018-11-29     2065  0.076126  0.078322
# 777010     zurcoin    ZUR     Zurcoin 2018-11-29     1596  0.000384  0.000385
# 462116      0xcert    ZXC      0xcert 2018-11-29     1034  0.002012  0.002091
# 820766   zayedcoin    ZYD   Zayedcoin 2018-11-29     1662  0.002476  0.002480
# 739248    zozocoin    ZZC    ZoZoCoin 2018-11-29     1541  0.015859  0.027383
#
# ...

# %%
print("Number of cryptocurrencies listed: ")
latest_crypto['symbol'].nunique()
# Out:
# Number of cryptocurrencies listed:
# 2005

# %%
# Filter the cryptocurrencies by rank and select the top 10
top_10_cryptos = latest_crypto[latest_crypto['ranknow'] <= 10]

# Sort the top 10 cryptocurrencies by rank in ascending order
top_10_cryptos_sorted = top_10_cryptos.sort_values(by='ranknow', ascending=True)

# Now, 'top_10_cryptos_sorted' contains the top 10 cryptocurrencies by rank in ascending order
top_10_cryptos_sorted
# Out:
#                slug symbol          name       date  ranknow         open  \
# 2041        bitcoin    BTC       Bitcoin 2018-11-29        1  4269.000000
# 3985         ripple    XRP           XRP 2018-11-29        2     0.391862
# 5196       ethereum    ETH      Ethereum 2018-11-29        3   122.720000
# 6774        stellar    XLM       Stellar 2018-11-29        4     0.161831
# 7269   bitcoin-cash    BCH  Bitcoin Cash 2018-11-29        5   190.100000
# 7786            eos    EOS           EOS 2018-11-29        6     3.290000
# 9828       litecoin    LTC      Litecoin 2018-11-29        7    34.720000
# 11197        tether   USDT        Tether 2018-11-29        8     0.995164
# 11218    bitcoin-sv    BSV    Bitcoin SV 2018-11-29        9    97.930000
# 11643       cardano    ADA       Cardano 2018-11-29       10     0.042269
#
#               high          low        close        volume        market  \
# 2041   4413.020000  4145.770000  4278.850000  6.503348e+09  7.445102e+10
# ...

# %%
# Plotting the top X currencies according to market valuation
#name = latest_df['name'].unique()
x=10
currency  = []
marketval = []
x_currencies = name[:x]
for i, cn in enumerate(x_currencies):
     filtered = top10_df[(latest_crypto['name']==str(cn))]
     currency.append(str(cn))
     marketval.append(filtered['market'].values[0])

f, ax = plt.subplots(figsize=(20, 8)) 
g = sns.barplot( y = currency, x = marketval, palette=sns.cubehelix_palette(x, reverse=True))
plt.title("Top X Cryptocurrencies Marketval")
ax.set_xticklabels(ax.get_xticks())
fig=plt.gcf()
plt.show()
# Out:
# C:\Users\43197\AppData\Local\Temp\ipykernel_5784\2594724811.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered = top10_df[(latest_crypto['name']==str(cn))]
# C:\Users\43197\AppData\Local\Temp\ipykernel_5784\2594724811.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticks())

# %%
currency  = []
volume = []
x_currencies = name[:x]
for i, cn in enumerate(x_currencies):
     filtered = top10_df[(top10_df['name']==str(cn))]
     currency.append(str(cn))
     volume.append(filtered['volume'].values[0])
        
f, ax = plt.subplots(figsize=(20, 8)) 
g = sns.barplot( y = currency, x = volume, palette=sns.cubehelix_palette(x, reverse=True))
plt.title("Top X Cryptocurrencies Volume")
ax.set_xticklabels(ax.get_xticks())
fig=plt.gcf()
plt.show()
# Out:
# C:\Users\43197\AppData\Local\Temp\ipykernel_5784\1898255620.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticks())

# %%
# Filter the cryptocurrencies by rank and select the top 10
top_10_cryptos = latest_crypto[latest_crypto_df['ranknow'] <= 10]

# Sort the top 10 cryptocurrencies by rank in ascending order
top_10_cryptos_sorted = top_10_cryptos.sort_values(by='ranknow', ascending=True)

# Now, 'top_10_cryptos_sorted' contains the top 10 cryptocurrencies by rank in ascending order
top_10_cryptos_sorted
# Out:
#                slug symbol          name       date  ranknow         open  \
# 2041        bitcoin    BTC       Bitcoin 2018-11-29        1  4269.000000
# 3985         ripple    XRP           XRP 2018-11-29        2     0.391862
# 5196       ethereum    ETH      Ethereum 2018-11-29        3   122.720000
# 6774        stellar    XLM       Stellar 2018-11-29        4     0.161831
# 7269   bitcoin-cash    BCH  Bitcoin Cash 2018-11-29        5   190.100000
# 7786            eos    EOS           EOS 2018-11-29        6     3.290000
# 9828       litecoin    LTC      Litecoin 2018-11-29        7    34.720000
# 11197        tether   USDT        Tether 2018-11-29        8     0.995164
# 11218    bitcoin-sv    BSV    Bitcoin SV 2018-11-29        9    97.930000
# 11643       cardano    ADA       Cardano 2018-11-29       10     0.042269
#
#               high          low        close        volume        market  \
# 2041   4413.020000  4145.770000  4278.850000  6.503348e+09  7.445102e+10
# ...

# %%
num_cryptos = crypto_markets.shape[0]
print("Number of cryptocurrencies listed:", num_cryptos)
# Out:
# Number of cryptocurrencies listed: 942297

# %%
num_symbols = crypto_markets['symbol'].nunique()
print("Number of symbols listed:", num_symbols)
# Out:
# Number of symbols listed: 2005

# %%
# Sort the DataFrame by market capitalization
#drop 'some columns
crypto_markets1=crypto_markets.drop(crypto_markets[['slug','date','open','high','low','close','close_ratio']],axis=1)
sorted_df = crypto_markets1.sort_values(by='market', ascending=False)

# Drop duplicates based on the 'symbol' column, keeping only the first occurrence (highest market cap)
top_cryptos_by_symbol = sorted_df.drop_duplicates(subset='symbol', keep='first')

# Print the cryptocurrencies with the highest market capitalization for each symbol
print("Cryptocurrencies with the highest market capitalization for each symbol:")
print(top_cryptos_by_symbol.head(20))
# Out:
# Cryptocurrencies with the highest market capitalization for each symbol:
#       symbol              name  ranknow        volume        market   spread
# 1693     BTC           Bitcoin        1  1.274060e+10  3.265025e+11  2201.40
# 4876     ETH          Ethereum        3  5.746760e+09  1.354007e+11   162.41
# 3659     XRP               XRP        2  2.395150e+09  1.308535e+11     0.41
# 6925     BCH      Bitcoin Cash        5  1.188960e+10  6.617106e+10  1530.59
# 11314    ADA           Cardano       10  5.934300e+08  2.888587e+10     0.29
# 9482     LTC          Litecoin        7  1.966600e+09  1.948262e+10    58.93
# 7572     EOS               EOS        6  4.870720e+09  1.776945e+10     4.01
# 17037    XEM               NEM       15  1.231730e+08  1.658448e+10     0.28
# 6444     XLM           Stellar        4  1.513270e+09  1.602204e+10     0.36
# 13929  MIOTA              IOTA       13  1.117890e+09  1.491588e+10     1.81
# ...

# %%
print("Number of cryptocurrencies listed: ")
latest_df['symbol'].nunique()
# Number of cryptocurrencies listed: 1461
# Out:
# Number of cryptocurrencies listed:
# 3

# %%
#Old and new tokens

# starting dates for all currencies
start_df = pd.DataFrame({'start_date' : crypto_markets.groupby( [ "name", "ranknow"] )['date'].min()}).reset_index()

# List the oldest ones
print("Oldest Cryptocurrencies")
start_df.sort_values(['start_date']).head(20)
# Out:
# Oldest Cryptocurrencies
#               name  ranknow start_date
# 231        Bitcoin        1 2013-04-28
# 1284      Novacoin      700 2013-04-28
# 1241      Namecoin      371 2013-04-28
# 1776     Terracoin      895 2013-04-28
# 1393      Peercoin      159 2013-04-28
# 1089      Litecoin        7 2013-04-28
# 1181       Mincoin     1520 2013-05-03
# 760    Feathercoin      415 2013-05-03
# 787       Freicoin     1412 2013-05-03
# 1004        Ixcoin     1301 2013-05-08
# 201         BitBar     1389 2013-05-09
# 1964     WorldCoin     1283 2013-05-22
# 584    Digitalcoin     1404 2013-06-09
# 847       GoldCoin      884 2013-06-14
# 107       Argentum      969 2013-07-04
# 1404   Phoenixcoin     1391 2013-07-04
# 759       Fastcoin     1450 2013-07-04
# 1164      Megacoin     1410 2013-07-07
# 969   Infinitecoin     1871 2013-07-10
# 1453     Primecoin      361 2013-07-11

# %%
# Rank

crypto_markets[crypto_markets['ranknow'] <= 20].groupby('ranknow').name.unique()
# Out:
# ranknow
# 1              [Bitcoin]
# 2                  [XRP]
# 3             [Ethereum]
# 4              [Stellar]
# 5         [Bitcoin Cash]
# 6                  [EOS]
# 7             [Litecoin]
# 8               [Tether]
# 9           [Bitcoin SV]
# 10             [Cardano]
# 11              [Monero]
# 12                [TRON]
# 13                [IOTA]
# 14                [Dash]
# 15                 [NEM]
# 16        [Binance Coin]
# 17                 [NEO]
# 18    [Ethereum Classic]
# 19               [Zcash]
# 20        [Bitcoin Gold]
# Name: name, dtype: object

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import boxcox
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA
import warnings
from itertools import product
from datetime import datetime
from statsmodels.tsa.seasonal import STL

# Load the CSV file into a DataFrame
btc_data = pd.read_csv("Bitcoin_prices.csv")
eth_data = pd.read_csv("Ethereum_prices.csv")

#concatenate the DataFrames vertically
combined_df = pd.concat([btc_data, eth_data], ignore_index=True)

# %%
#Save the combined Dataframe to a new CSV file
combined_df.to_csv('combined.csv',index=False)

# %%
eth_data
# Out:
#             Date         Open         High          Low        Close  \
# 0     2017-11-09   308.644989   329.451996   307.056000   320.884003
# 1     2017-11-10   320.670990   324.717987   294.541992   299.252991
# 2     2017-11-11   298.585999   319.453003   298.191986   314.681000
# 3     2017-11-12   314.690002   319.153015   298.513000   307.907990
# 4     2017-11-13   307.024994   328.415009   307.024994   316.716003
# ...          ...          ...          ...          ...          ...
# 1973  2023-04-05  1870.965088  1937.497559  1865.941895  1909.114014
# 1974  2023-04-06  1909.143555  1909.271729  1857.085083  1872.922607
# 1975  2023-04-07  1872.734131  1882.299194  1845.993896  1865.636108
# 1976  2023-04-08  1864.679077  1879.107788  1848.875488  1849.498169
# 1977  2023-04-09  1848.805420  1859.898682  1834.872803  1834.872803
#
#         Adj Close       Volume
# 0      320.884003    893249984
# 1      299.252991    885985984
# 2      314.681000    842300992
# ...

# %%
new_data = pd.read_csv("combined.csv")
new_data
# Out:
#             Date         Open         High          Low        Close  \
# 0     2014-09-18   456.859985   456.859985   413.104004   424.440002
# 1     2014-09-19   424.102997   427.834991   384.532013   394.795990
# 2     2014-09-20   394.673004   423.295990   389.882996   408.903992
# 3     2014-09-21   408.084991   412.425995   393.181000   398.821014
# 4     2014-09-22   399.100006   406.915985   397.130005   402.152008
# ...          ...          ...          ...          ...          ...
# 5098  2023-04-05  1870.965088  1937.497559  1865.941895  1909.114014
# 5099  2023-04-06  1909.143555  1909.271729  1857.085083  1872.922607
# 5100  2023-04-07  1872.734131  1882.299194  1845.993896  1865.636108
# 5101  2023-04-08  1864.679077  1879.107788  1848.875488  1849.498169
# 5102  2023-04-09  1848.805420  1859.898682  1834.872803  1834.872803
#
#         Adj Close       Volume
# 0      424.440002     34483200
# 1      394.795990     37919700
# 2      408.903992     36863600
# ...
